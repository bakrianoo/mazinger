# %% [markdown]
# # 🎬 Mazinger Dubber — Colab Quickstart
#
# Run the **Mazinger Studio** web UI on a free Colab T4 GPU.
#
# **Before you start:** confirm the GPU is on — `Runtime → Change runtime type → T4 GPU`.
#
# Then run the two cells below in order:
#
# 1. **Install** Mazinger and `ffmpeg` (~2–3 min).
# 2. **Launch** the web UI. A public `https://…gradio.live` link will be printed — open it in a new tab.
#
# > Keep this Colab tab open while you use the UI. Closing it stops the server.

# %%
# 1. Install ffmpeg + Mazinger (full pipeline + Studio web UI)
# !apt-get -qq install -y ffmpeg
# !pip install -q "mazinger[all]"

# %% [markdown]
# ## ▶️ Launch the Web UI
#
# The flags below install a free local LLM (Ollama) and pre-download the Faster-Whisper model on first run — no API keys required.
#
# When you see a line like `Running on public URL: https://xxxx.gradio.live`, click it to open the Studio.

# %%
# 2. Launch Mazinger Studio (Gradio share link will be printed below)
# !mazinger web --with-ollama --with-faster-whisper
